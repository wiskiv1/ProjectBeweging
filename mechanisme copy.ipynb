# %% [markdown]
# # Mechanisme : Ruben Snijders en Witse Panneels
#
# mechanisme: 18 (R) + 23 (W) = 41 + 1 => **2** => Pantograaf

# %% [markdown]
# ## Kinematica

# %%
# imports and initialization

import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import fsolve
from matplotlib.animation import FuncAnimation
from IPython.display import HTML

# %matplotlib widget

# %%
# zetten van de kinematische parameters
# Alle eenheden zijn in meter of radialen

phi0 = 0 #rad
d1 = 2.11 #m
d2 = -0.71 #m
d3 = -0.312290 #m

r1 = 0.25 #m
r2 = 1.54 #m
r3 = 0.5 #m
r4 = 1.56 #m
r5 = 2.4 #m
r6 = 2 #m
r7 = 5 #m

l41 = 0.85 #m
l51 = 0.4 #m
l71 = 0.5 #m

# l42, l52 en l72 bekomen we door rx - lx1
l42 = r4 - l41
l52 = r5 - l51
l72 = r7 - l71

#de beginwaarden voor de hoeken voor fsolve

phi2_init = 2.827472
phi3_init = -0.475431
phi4_init = 0.326608
phi5_init = 0.417741
phi6_init = 0.417741
phi7_init = 2.666161

# Tijd + simulatie parameters
t_begin =  0     # start time of simulation
t_end   = 25     # end time of simulation
Ts      =  0.10  # time step of simulation
t = np.arange(t_begin, t_end + Ts, Ts)  # time vector

#initialization of driver
omega = 0.5      # driver frequency
A     = 0.29     # amplitude
# angular position, velocity and acceleration:
phi1   = 2.53 + A * np.sin(omega * t)
dphi1  = omega * A * np.cos(omega * t)
ddphi1 = -omega ** 2 * A * np.sin(omega * t)

# %% [markdown]
# ## berekeningen

# %%
# Define loop closure equations
def loop_closure_eqs(phi_init, phi1, d1, d2, d3, r1, r2, r3, r6, l41, l42, l51, l52, l71, phi0):
    phi2 = phi_init[0]
    phi3 = phi_init[1]
    phi4 = phi_init[2]
    phi5 = phi_init[3]
    phi6 = phi_init[4]
    phi7 = phi_init[5]

    # Loop closure equations
    F1 = r1 * np.cos(phi1) + l41 * np.cos(phi4) - r2 * np.cos(phi2) - d1 * np.cos(phi0)
    F2 = r1 * np.sin(phi1) + l41 * np.sin(phi4) - r2 * np.sin(phi2) - d1 * np.sin(phi0)
    F3 = r2 * np.cos(phi2) + l42 * np.cos(phi4) + r3 * np.cos(phi3) - d2 * np.cos(phi0) - d3 * np.sin(phi0) - l51 * np.cos(phi5)
    F4 = r2 * np.sin(phi2) + l42 * np.sin(phi4) + r3 * np.sin(phi3) - d2 * np.sin(phi0) + d3 * np.cos(phi0) - l51 * np.sin(phi5)
    F5 = r3 * np.cos(phi3) + l52 * np.cos(phi5) + l71 * np.cos(phi7) - r6 * np.cos(phi6)
    F6 = r3 * np.sin(phi3) + l52 * np.sin(phi5) + l71 * np.sin(phi7) - r6 * np.sin(phi6)

    return [F1, F2, F3, F4, F5, F6]

# %%
# Definieer de kinematische berekeningen van de pantograaf

def kinematics_pantograaf(d1, d2, d3, r1, r2, r3, r6, l41, l42, l51, l52, l71, phi0, phi1, dphi1, ddphi1, 
                          phi2_init, phi3_init, phi4_init, phi5_init, phi6_init, phi7_init, t):
    global phi2, phi3, phi4, phi5, phi6, phi7, dphi2, dphi3, dphi4, dphi5, dphi6, dphi7, ddphi2, ddphi3, ddphi4, ddphi5, ddphi6, ddphi7, cond
    phi2   = np.zeros_like(t)
    phi3   = np.zeros_like(t)
    phi4   = np.zeros_like(t)
    phi5   = np.zeros_like(t)
    phi6   = np.zeros_like(t)
    phi7   = np.zeros_like(t)
    dphi2   = np.zeros_like(t)
    dphi3   = np.zeros_like(t)
    dphi4   = np.zeros_like(t)
    dphi5   = np.zeros_like(t)
    dphi6   = np.zeros_like(t)
    dphi7   = np.zeros_like(t)
    ddphi2   = np.zeros_like(t)
    ddphi3   = np.zeros_like(t)
    ddphi4   = np.zeros_like(t)
    ddphi5   = np.zeros_like(t)
    ddphi6   = np.zeros_like(t)
    ddphi7   = np.zeros_like(t)

    cond   = np.zeros_like(t)

    optim_options = {"full_output":True}  # options for fsolve

    for k, time in enumerate(t):
        # Position Analysis
        x, _, ier, message  = fsolve(lambda x: loop_closure_eqs(x, phi1[k], d1, d2, d3, r1, r2, r3, r6, l41, l42, l51, l52, l71, phi0), [phi2_init, phi3_init, phi4_init, phi5_init, phi6_init, phi7_init], **optim_options)

        if ier != 1:
            print("The fsolve exit flag was not 1, probably no convergence!")
            print(message)

        phi2[k] = x[0]
        phi3[k] = x[1]
        phi4[k] = x[2]
        phi5[k] = x[3]
        phi6[k] = x[4]
        phi7[k] = x[5]


        # Velocity Analysis
        A = np.array([[r2 * np.sin(phi2[k]), 0, -l41 * np.sin(phi4[k]), 0, 0, 0],
                      [-r2 * np.cos(phi2[k]),0, l41 * np.cos(phi4[k]), 0, 0, 0],
                      [-r2 * np.sin(phi2[k]), -r3 * np.sin(phi3[k]), -l42 * np.sin(phi4[k]), l51 * np.sin(phi5[k]), 0, 0],
                      [r2 * np.cos(phi2[k]), r3 * np.cos(phi3[k]), l42 * np.cos(phi4[k]), -l51 * np.cos(phi5[k]), 0, 0],
                      [0, -r3 * np.sin(phi3[k]), 0, -l52 * np.sin(phi5[k]), r6 * np.sin(phi6[k]), -l71 * np.sin(phi7[k])],
                      [0, r3 * np.cos(phi3[k]), 0, l52 * np.cos(phi5[k]), -r6 * np.cos(phi6[k]), l71 * np.cos(phi7[k])]])
        B = np.array([r1 * np.sin(phi1[k]) * dphi1[k],
                      -r1 * np.cos(phi1[k]) * dphi1[k],
                      0,
                      0,
                      0,
                      0])

        x = np.linalg.solve(A, B)
        dphi2[k] = x[0]
        dphi3[k] = x[1]
        dphi4[k] = x[2]
        dphi5[k] = x[3]
        dphi6[k] = x[4]
        dphi7[k] = x[5]
        cond[k]  = np.linalg.cond(A)

        # Acceleration Analysis
        B = np.array([r1 * np.cos(phi1[k]) * dphi1[k]**2 + r1 * np.sin(phi1[k]) * ddphi1[k] - r2 * np.cos(phi2[k]) * dphi2[k]**2 + l41 * np.cos(phi4[k]) * dphi4[k]**2,
                      r1 * np.sin(phi1[k]) * dphi1[k]**2 - r1 * np.cos(phi1[k]) * ddphi1[k] - r2 * np.sin(phi2[k]) * dphi2[k]**2 + l41 * np.sin(phi4[k]) * dphi4[k]**2,
                      r2 * np.cos(phi2[k]) * dphi2[k]**2 + r3 * np.cos(phi3[k]) * dphi3[k]**2 + l42 * np.cos(phi4[k]) * dphi4[k]**2 - l51 * np.cos(phi5[k]) * dphi5[k]**2,
                      r2 * np.sin(phi2[k]) * dphi2[k]**2 + r3 * np.sin(phi3[k]) * dphi3[k]**2 + l42 * np.sin(phi4[k]) * dphi4[k]**2 - l51 * np.sin(phi5[k]) * dphi5[k]**2,
                      r3 * np.cos(phi3[k]) * dphi3[k]**2 + l52 * np.cos(phi5[k]) * dphi5[k]**2 - r6 * np.cos(phi6[k]) * dphi6[k]**2 + l71 * np.cos(phi7[k]) * dphi7[k]**2,
                      r3 * np.sin(phi3[k]) * dphi3[k]**2 + l52 * np.sin(phi5[k]) * dphi5[k]**2 - r6 * np.sin(phi6[k]) * dphi6[k]**2 + l71 * np.sin(phi7[k]) * dphi7[k]**2])

        x = np.linalg.solve(A, B)
        ddphi2[k] = x[0]
        ddphi3[k] = x[1]
        ddphi4[k] = x[2]
        ddphi5[k] = x[3]
        ddphi6[k] = x[4]
        ddphi7[k] = x[5]

        # Next iteration step
        phi2_init = phi2[k] + (t[1] - t[0]) * dphi2[k]
        phi3_init = phi3[k] + (t[1] - t[0]) * dphi3[k]
        phi4_init = phi4[k] + (t[1] - t[0]) * dphi4[k]
        phi5_init = phi5[k] + (t[1] - t[0]) * dphi5[k]
        phi6_init = phi6[k] + (t[1] - t[0]) * dphi6[k]
        phi7_init = phi7[k] + (t[1] - t[0]) * dphi7[k]

# %%
# Helper functions

def getCartesianCoordinates(r, phi):
    rotatie_matrix = np.array([[np.cos(phi), -np.sin(phi)],
                                [np.sin(phi), np.cos(phi)]])
    return np.dot(rotatie_matrix, r)

def drawLink(P1, P2, graph):
    # graph.plot([P1[0], P2[0]], [P1[1], P2[1]], "-k")
    graph.plot(P1[0], P2[0], P1[1], P2[1])

# %%
# run the simulation
kinematics_pantograaf(d1, d2, d3, r1, r2, r3, r6, l41, l42, l51, l52, l71, phi0, phi1, dphi1, ddphi1, phi2_init, phi3_init, phi4_init, phi5_init, phi6_init, phi7_init, t)

# %%
# Hoekpositie, snelheid en versnelling van alle hoekpunten
plt.ion()

# Zorg dat alle hoeken tussen 0 en 2pi liggen
def wrap_angle(angle):
    return np.mod(angle, 2 * np.pi)

fig1, ax1 = plt.subplots(nrows=7,ncols=3,constrained_layout=True)
fig1.suptitle("Position, velocity and acceleration")

ax1[0,0].plot(t, wrap_angle(phi1))
ax1[0,0].set_ylabel(r'$\phi_1$ [rad]')

ax1[1,0].plot(t, wrap_angle(phi2))
ax1[1,0].set_ylabel(r'$\phi_2$ [rad]')

ax1[2,0].plot(t, wrap_angle(phi3))
ax1[2,0].set_ylabel(r'$\phi_3$ [rad]')

ax1[3,0].plot(t, wrap_angle(phi4))
ax1[3,0].set_ylabel(r'$\phi_4$ [rad]')

ax1[4,0].plot(t, wrap_angle(phi5))
ax1[4,0].set_ylabel(r'$\phi_5$ [rad]')

ax1[5,0].plot(t, wrap_angle(phi6))
ax1[5,0].set_ylabel(r'$\phi_6$ [rad]')

ax1[6,0].plot(t, wrap_angle(phi7))
ax1[6,0].set_ylabel(r'$\phi_7$ [rad]')
ax1[6,0].set_xlabel('t [s]')

ax1[0,1].plot(t, dphi1)
ax1[0,1].set_ylabel(r'$\dot{\phi}_1$ [rad/s]')

ax1[1,1].plot(t, dphi2)
ax1[1,1].set_ylabel(r'$\dot{\phi}_2$ [rad/s]')

ax1[2,1].plot(t, dphi3)
ax1[2,1].set_ylabel(r'$\dot{\phi}_3$ [rad/s]')

ax1[3,1].plot(t, dphi4)
ax1[3,1].set_ylabel(r'$\dot{\phi}_4$ [rad/s]')

ax1[4,1].plot(t, dphi5)
ax1[4,1].set_ylabel(r'$\dot{\phi}_5$ [rad/s]')

ax1[5,1].plot(t, dphi6)
ax1[5,1].set_ylabel(r'$\dot{\phi}_6$ [rad/s]')

ax1[6,1].plot(t, dphi7)
ax1[6,1].set_ylabel(r'$\dot{\phi}_7$ [rad/s]')
ax1[6,1].set_xlabel('t [s]')

ax1[0,2].plot(t, ddphi1)
ax1[0,2].set_ylabel(r'$\ddot{\phi}_1 [\text{rad/s}^2]$')

ax1[1,2].plot(t, ddphi2)
ax1[1,2].set_ylabel(r'$\ddot{\phi}_2 [\text{rad/s}^2]$')

ax1[2,2].plot(t, ddphi3)
ax1[2,2].set_ylabel(r'$\ddot{\phi}_3 [\text{rad/s}^2]$')

ax1[3,2].plot(t, ddphi4)
ax1[3,2].set_ylabel(r'$\ddot{\phi}_4 [\text{rad/s}^2]$')

ax1[4,2].plot(t, ddphi5)
ax1[4,2].set_ylabel(r'$\ddot{\phi}_5 [\text{rad/s}^2]$')

ax1[5,2].plot(t, ddphi6)
ax1[5,2].set_ylabel(r'$\ddot{\phi}_6 [\text{rad/s}^2]$')

ax1[6,2].plot(t, ddphi7)
ax1[6,2].set_ylabel(r'$\ddot{\phi}_7 [\text{rad/s}^2]$')
ax1[6,2].set_xlabel('t [s]')

plt.show(fig1)

# plot of condition number:
figc, axc = plt.subplots()
figc.suptitle("Condition number of matrix A")

axc.plot(t, cond)
axc.set_ylabel("cond(A)")
plt.show(figc)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Animatie pantograaf
plt.ioff()               # don't show animation figure until drawn explicitly:
fig2, ax = plt.subplots() # Initialize the figure

# Definieer punt A, B en E als grond punten
A = np.array([0,0])
B = np.array([d1, 0])
E = np.array([d1 + d2, -d3])

# afmetingen canvas => statisch voor nu
x_left   = -2.5
y_bottom = -1
x_right  = 6
y_top    = 7.5

# draw loop
def draw(frame):
    global fig2, ax, x_left, x_right, y_bottom, y_top, A, B, E
    ax.cla()         # Clear the current axes
    # ax.axis('equal') # Ensures 1 unit on x == 1 unit on y
    ax.set_xlabel('[m]')
    ax.set_ylabel('[m]')
    ax.set_xlim([x_left, x_right])
    ax.set_ylim([y_bottom, y_top])
    time_now = t[frame]
    angle = phi1[frame]
    ax.set_title(f'Time {time_now: .2f}')
    # ax.set_title(f'Angle {angle: .2f}')
    # ax.set_title(f'Frame {frame}')

    # Bereken alle niet vaste punten
    C = A + getCartesianCoordinates([r1, 0], phi1[frame])
    D = B + getCartesianCoordinates([r2, 0], phi2[frame])
    G = C + getCartesianCoordinates([r4, 0], phi4[frame])
    F = E + getCartesianCoordinates([l51, 0], phi5[frame])
    H = E + getCartesianCoordinates([r5, 0], phi5[frame])
    I = H + getCartesianCoordinates([l71, 0], phi7[frame])
    J = H + getCartesianCoordinates([r7, 0], phi7[frame])

    ax.plot([A[0], C[0]], [A[1], C[1]]) # stang 1
    ax.plot([B[0], D[0]], [B[1], D[1]]) # stang 2
    ax.plot([G[0], F[0]], [G[1], F[1]]) # stang 3
    ax.plot([C[0], G[0]], [C[1], G[1]]) # stang 4
    ax.plot([E[0], H[0]], [E[1], H[1]]) # stang 5
    ax.plot([G[0], I[0]], [G[1], I[1]]) # stang 6
    ax.plot([H[0], J[0]], [H[1], J[1]]) # stang 7

    ax.text(A[0], A[1], "A")
    ax.text(B[0], B[1], 'B')
    ax.text(C[0], C[1], 'C')
    ax.text(D[0], D[1], 'D')
    ax.text(E[0], E[1], 'E')
    ax.text(F[0], F[1], 'F')
    ax.text(G[0], G[1], 'G')
    ax.text(H[0], H[1], 'H')
    ax.text(I[0], I[1], 'I')

    return(ax)

# animate the mechanism:
frames = int((2 * np.pi / omega) / Ts) # aantal frames voor 1 periode
ani = FuncAnimation(fig2, draw, frames, interval=50, repeat=False)

# %% [markdown]
# ## animatie

# %%
# Toon animatie
ani_html = ani.to_jshtml(default_mode='once')
plt.close(fig2)
HTML(ani_html)
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
# ...

# %% [markdown]
# # Toepassing
#
# Stroom arm / stroom afnemer van een trein of elektrische vrachtwagen
#
# ![trein](https://upload.wikimedia.org/wikipedia/commons/thumb/d/d2/Stroomafnemer_Plan_V.jpg/250px-Stroomafnemer_Plan_V.jpg)
#
# Opwaartse kracht is tussen de 70 en 120 Newton => we pakken 90N voor het gebruiksgemak [Bron](https://www.mts.com/en/articles/rail/high-performance-pantograph)
#
# Wrijvingscoëfficiënt tussen staal en staal is 0.1...0.15 (dynamisch) [Bron](https://www.werktuigbouw.nl/abc/cof.htm)
#
# [Vido trein pantograaf](https://www.youtube.com/watch?v=QHQpIS4zn2Y) => zakken duurt 5~6 seconden

# %% [markdown]
# ## Inverse dynamica

# %%
# Definiëring nodige krachten
# Overal zwaartekracht? enkel op punt J een externe neerwaartse kracht  

# stalen buis van diameter ~30mm (Redelijk grote overschatting, want zelfde stijfheid kan "goedkoper" behaald worden)
massadichtheid = 5 # kg/m

masses = {
    1: r1 * massadichtheid,
    2: r2 * massadichtheid,
    3: r3 * massadichtheid,
    4: r4 * massadichtheid,
    5: r5 * massadichtheid,
    6: r6 * massadichtheid,
    7: r7 * massadichtheid,
}

# Traagheidsmomenten (veralgemening voor simpele dunne buis)
# I = 1/12 * m * l^2
inertias = {
    1: masses[1] * r1**2 / 12,
    2: masses[2] * r2**2 / 12,
    3: masses[3] * r3**2 / 12,
    4: masses[4] * r4**2 / 12,
    5: masses[5] * r5**2 / 12,
    6: masses[6] * r6**2 / 12,
    7: masses[7] * r7**2 / 12,
}

Cable_force = 90 #N
dcf = 0.15 # dynamische wrijvingscoëfficiënt

# %%
# Versnelling van alle punten en massacentra  
def fixed_point(x, y):
    return np.tile(np.array([x, y]), (len(t), 1))

def link_vector(L, angle):
    return np.column_stack((L*np.cos(angle), L*np.sin(angle)))

def point_acceleration(base_acc, L, angle, angular_velocity, angular_acceleration):
    return base_acc + np.column_stack((
        -L*np.cos(angle)*angular_velocity**2 - L*np.sin(angle)*angular_acceleration,
        -L*np.sin(angle)*angular_velocity**2 + L*np.cos(angle)*angular_acceleration
    ))

zero_acc = np.zeros((len(t), 2))
A_traj = fixed_point(0.0, 0.0)
B_traj = fixed_point(d1, 0.0)
E_traj = fixed_point(d1 + d2, -d3)
C = A_traj + link_vector(r1, phi1)
D = B_traj + link_vector(r2, phi2)
G = C + link_vector(r4, phi4)
F = E_traj + link_vector(l51, phi5)
H = E_traj + link_vector(r5, phi5)
I = H + link_vector(l71, phi7)
J = H + link_vector(r7, phi7)
points = {'A': A_traj, 'B': B_traj, 'C': C, 'D': D, 'E': E_traj, 'F': F, 'G': G, 'H': H, 'I': I, 'J': J}

# Massacentra: midden van de volledige lichamen.
cg = {
    1: A_traj + link_vector(r1/2, phi1),
    2: B_traj + link_vector(r2/2, phi2),
    3: G + link_vector(r3/2, phi3),
    4: C + link_vector(r4/2, phi4),
    5: E_traj + link_vector(r5/2, phi5),
    6: G + link_vector(r6/2, phi6),
    7: H + link_vector(r7/2, phi7)
}

aC = point_acceleration(zero_acc, r1, phi1, dphi1, ddphi1)
aG = point_acceleration(aC, r4, phi4, dphi4, ddphi4)
aH = point_acceleration(zero_acc, r5, phi5, dphi5, ddphi5)
acc_cg = {
    1: point_acceleration(zero_acc, r1/2, phi1, dphi1, ddphi1),
    2: point_acceleration(zero_acc, r2/2, phi2, dphi2, ddphi2),
    3: point_acceleration(aG, r3/2, phi3, dphi3, ddphi3),
    4: point_acceleration(aC, r4/2, phi4, dphi4, ddphi4),
    5: point_acceleration(zero_acc, r5/2, phi5, dphi5, ddphi5),
    6: point_acceleration(aG, r6/2, phi6, dphi6, ddphi6),
    7: point_acceleration(aH, r7/2, phi7, dphi7, ddphi7)
}

# %% [markdown]
# ### Newton-Euler inverse dynamica
#
# Voor elk bewegend gelid worden drie vergelijkingen opgesteld:
#
# $$\sum F_x = m a_{G,x}, \qquad \sum F_y = m a_{G,y}, \qquad \sum M_G = J_G \ddot{\phi}.$$
#
# De onbekenden zijn de twee krachtcomponenten in tien verbindingen en het aandrijfmoment in $A$:
#
# $$\{R_A, R_B, R_E, R_C, R_D, R_{G,3}, R_{G,6}, R_F, R_H, R_I, M_A\}.$$
#
# Het drievoudige scharnier in $G$ wordt gemodelleerd door twee onafhankelijke reactiekrachten: de kracht tussen gelid 4 en 3 en de kracht tussen gelid 4 en 6. Hierdoor zijn er $21$ onbekenden voor $7 \times 3 = 21$ evenwichtsvergelijkingen.

# %%
# Opstellen van de matrix methode

# (naam, eerste lichaam of grond, tweede lichaam, aangrijpingspunt).
# Een positieve onbekende kracht is de kracht van het eerste lichaam op het tweede.
joints = [
    ('A', None, 1, 'A'),
    ('B', None, 2, 'B'),
    ('E', None, 5, 'E'),
    ('C', 1, 4, 'C'),
    ('D', 2, 4, 'D'),
    ('G_43', 4, 3, 'G'),
    ('G_46', 4, 6, 'G'),
    ('F', 3, 5, 'F'),
    ('H', 5, 7, 'H'),
    ('I', 6, 7, 'I')
]
unknown_forces = [f'{name}_{axis}' for name, _, _, _ in joints for axis in ('x', 'y')] + ['M_A']

def cross2(r, force):
    return r[0]*force[1] - r[1]*force[0]

angular_accelerations = {
    1: ddphi1, 2: ddphi2, 3: ddphi3, 4: ddphi4,
    5: ddphi5, 6: ddphi6, 7: ddphi7
}

def dynamics_matrix(k, masses, inertias, gravity=9.81, external_forces=None, external_moments=None):
    """Maak M en b voor M * unknowns = b op moment k.

    Voorbeeld external_forces:
    {7: [('J', np.array([friction, -contact_force]))]}.
    """
    external_forces = {} if external_forces is None else external_forces
    external_moments = {} if external_moments is None else external_moments
    matrix = np.zeros((21, 21))
    rhs = np.zeros(21)

    for body in range(1, 8):
        row_x = 3 * (body - 1)
        row_y = row_x + 1
        row_m = row_x + 2
        rhs[row_x] = masses[body] * acc_cg[body][k][0]
        rhs[row_y] = masses[body] * acc_cg[body][k][1] + masses[body] * gravity
        rhs[row_m] = inertias[body] * angular_accelerations[body][k]

        for point_name, force in external_forces.get(body, []):
            force = np.asarray(force, dtype=float)
            rhs[row_x:row_y + 1] -= force
            arm = points[point_name][k] - cg[body][k]
            rhs[row_m] -= cross2(arm, force)
        rhs[row_m] -= external_moments.get(body, 0.0)

    for joint_number, (_, body_from, body_to, point_name) in enumerate(joints):
        col_x = 2 * joint_number
        col_y = col_x + 1
        for body, sign in ((body_from, -1.0), (body_to, 1.0)):
            if body is None:
                continue
            row_x = 3 * (body - 1)
            row_y = row_x + 1
            row_m = row_x + 2
            arm = points[point_name][k] - cg[body][k]
            matrix[row_x, col_x] += sign
            matrix[row_y, col_y] += sign
            matrix[row_m, col_x] += -sign * arm[1]
            matrix[row_m, col_y] += sign * arm[0]

    matrix[2, 20] = 1.0  # Drive torque M_A acts on link 1.
    return matrix, rhs

# %%
# Solver van het stelsel lineaire vergelijkingen

def bereken_krachten(masses, inertias, gravity=9.81, external_forces=None, external_moments=None):
    """Los de krachten op; een externe kracht mag constant of tijdsafhankelijk zijn."""
    external_forces = {} if external_forces is None else external_forces
    solution = np.zeros((len(t), len(unknown_forces)))

    for k in range(len(t)):
        instantaneous_forces = {}
        for body, applied_forces in external_forces.items():
            instantaneous_forces[body] = []
            for point_name, force in applied_forces:
                force = np.asarray(force, dtype=float)
                if force.ndim == 2:
                    force = force[k]
                instantaneous_forces[body].append((point_name, force))

        matrix, rhs = dynamics_matrix(k, masses, inertias, gravity, instantaneous_forces, external_moments)
        solution[k] = np.linalg.solve(matrix, rhs)

    return dict(zip(unknown_forces, solution.T))

# %% [markdown]
# ### Berekenen van krachten/momenten

# %%
# draw plots normally again
plt.ion()

# %%
# Solve for needed torque in A for no external forces (no gravity)

solution_no_load = bereken_krachten(masses, inertias, gravity=0.0)

torque_A_no_load = solution_no_load['M_A']

fig_torque, ax_torque = plt.subplots()
ax_torque.plot(t, torque_A_no_load, label='$M_A$')
ax_torque.set_xlabel('Time [s]')
ax_torque.set_ylabel('Required torque in A [Nm]')
ax_torque.set_title('Required drive torque without gravity or external forces')
ax_torque.grid(True)
ax_torque.legend()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Nodig moment met zwaartekracht

solution_no_load = bereken_krachten(masses, inertias)

torque_A_no_load = solution_no_load['M_A']

fig_torque, ax_torque = plt.subplots()
ax_torque.plot(t, torque_A_no_load, label='$M_A$')
ax_torque.set_xlabel('Time [s]')
ax_torque.set_ylabel('Required torque in A [Nm]')
ax_torque.set_title('Required drive torque without external forces')
ax_torque.grid(True)
ax_torque.legend()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Nodig moment met zwaartekracht en penwrijving
# De penwrijving wordt gemodelleerd als een klein Coulomb-moment plus een viskeus moment
# dat de relatieve hoeksnelheid in elk scharnier tegenwerkt.

pin_coulomb_moment = 0.20      # Nm, aangenomen droog/frictiemoment per scharnier
pin_viscous_coefficient = 0.05 # Nms/rad, aangenomen viskeuze wrijving per scharnier
friction_speed_smoothing = 1e-3 # rad/s, vermijdt een sprong rond nul snelheid

angular_velocities = {
    1: dphi1, 2: dphi2, 3: dphi3, 4: dphi4,
    5: dphi5, 6: dphi6, 7: dphi7
}

def pin_friction_torque(relative_speed):
    return -pin_coulomb_moment*np.tanh(relative_speed/friction_speed_smoothing) - pin_viscous_coefficient*relative_speed

def friction_moments_at_time(k):
    external_moments = {body: 0.0 for body in range(1, 8)}
    for _, body_from, body_to, _ in joints:
        omega_from = 0.0 if body_from is None else angular_velocities[body_from][k]
        omega_to = angular_velocities[body_to][k]
        moment_on_to = pin_friction_torque(omega_to - omega_from)

        external_moments[body_to] += moment_on_to
        if body_from is not None:
            external_moments[body_from] -= moment_on_to

    return external_moments

def bereken_krachten_met_penwrijving(masses, inertias, gravity=9.81):
    solution = np.zeros((len(t), len(unknown_forces)))
    for k in range(len(t)):
        matrix, rhs = dynamics_matrix(k, masses, inertias, gravity=gravity, external_moments=friction_moments_at_time(k))
        solution[k] = np.linalg.solve(matrix, rhs)
    return dict(zip(unknown_forces, solution.T))

solution_gravity = bereken_krachten(masses, inertias)
solution_friction = bereken_krachten_met_penwrijving(masses, inertias)

torque_A_gravity = solution_gravity['M_A']
torque_A_friction = solution_friction['M_A']
power_A_friction = torque_A_friction*dphi1

print(f'Maximum moment met zwaartekracht: {np.max(np.abs(torque_A_gravity)):.2f} Nm')
print(f'Maximum moment met zwaartekracht en penwrijving: {np.max(np.abs(torque_A_friction)):.2f} Nm')
print(f'Maximum vermogen met penwrijving: {np.max(np.abs(power_A_friction)):.2f} W')

fig_torque, ax_torque = plt.subplots()
ax_torque.plot(t, torque_A_gravity, label='gravity only')
ax_torque.plot(t, torque_A_friction, label='gravity + pin friction')
ax_torque.set_xlabel('Time [s]')
ax_torque.set_ylabel('Required torque in A [Nm]')
ax_torque.set_title('Required drive torque with gravity and pin friction')
ax_torque.grid(True)
ax_torque.legend()
plt.show()

fig_power, ax_power = plt.subplots()
ax_power.plot(t, power_A_friction, label='$P_A$')
ax_power.set_xlabel('Time [s]')
ax_power.set_ylabel('Power [W]')
ax_power.set_title('Input power with gravity and pin friction')
ax_power.grid(True)
ax_power.legend()
plt.show()
# Out:
# Maximum moment met zwaartekracht: 947.22 Nm
# Maximum moment met zwaartekracht en penwrijving: 949.05 Nm
# Maximum vermogen met penwrijving: 130.77 W
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Nodig moment met zwaartekracht, kabelkracht en wrijving
# De kabel duwt neerwaarts op punt J; wrijving werkt hier in de positieve x-richting.
def gradual_force_profile(time, start, full_force, release, end):
    """0 -> 1 -> 0 factor for a gradually applied and released contact force."""
    return np.interp(time, [start, full_force, release, end], [0, 1, 1, 0], left=0, right=0)

# Tijdstippen waarop de pantograaf contact maakt met de kabel. Deze tijden kan je aanpassen.
contact_start = 7.8       # Start van contact: kracht is nog 0 N
contact_full_force = 9.0  # Vanaf hier is de volledige kracht aanwezig
contact_release = 9.8     # Vanaf hier neemt de kracht weer af
contact_end = 11.0        # Einde contact: kracht is terug 0 N

contact_factor = gradual_force_profile(t, contact_start, contact_full_force, contact_release, contact_end)
cable_force_profile = Cable_force * contact_factor
friction_force_profile = dcf * cable_force_profile

force_profile_at_J = np.column_stack((friction_force_profile, -cable_force_profile))
external_forces_cable = {
    7: [('J', force_profile_at_J)]
}

solution_cable = bereken_krachten(masses, inertias, external_forces=external_forces_cable)
torque_A_cable = solution_cable['M_A']

power_A_cable = torque_A_cable*dphi1
drive_speed_rpm = dphi1*60/(2*np.pi)

peak_torque_index = np.argmax(np.abs(torque_A_cable))
peak_power_index = np.argmax(np.abs(power_A_cable))

print('Motorselectie zonder penwrijving, met zwaartekracht, kabelkracht en kabelcontactwrijving:')
print(f'  Maximaal absoluut uitgangsmoment aan A = {np.max(np.abs(torque_A_cable)):.2f} Nm')
print(f'  RMS uitgangsmoment aan A = {np.sqrt(np.mean(torque_A_cable**2)):.2f} Nm')
print(f'  Maximaal absoluut uitgangsvermogen = {np.max(np.abs(power_A_cable)):.2f} W')
print(f'  Gemiddeld positief vermogen = {np.mean(np.maximum(power_A_cable, 0)):.2f} W')
print(f'  Maximale absolute uitgangssnelheid = {np.max(np.abs(drive_speed_rpm)):.2f} rpm')
print(f'  Moment bij piekmoment: t = {t[peak_torque_index]:.2f} s, M_A = {torque_A_cable[peak_torque_index]:.2f} Nm, n_A = {drive_speed_rpm[peak_torque_index]:.2f} rpm')
print(f'  Vermogen bij piekvermogen: t = {t[peak_power_index]:.2f} s, P_A = {power_A_cable[peak_power_index]:.2f} W, M_A = {torque_A_cable[peak_power_index]:.2f} Nm')

fig_torque_cable, ax_torque_cable = plt.subplots()
ax_torque_cable.plot(t, torque_A_cable)
ax_torque_cable.set_xlabel('Time [s]')
ax_torque_cable.set_ylabel('Required torque in A [Nm]')
ax_torque_cable.set_title('Required drive torque with cable force')
ax_torque_cable.grid(True)
plt.show()

fig_power_cable, ax_power_cable = plt.subplots()
ax_power_cable.plot(t, power_A_cable)
ax_power_cable.set_xlabel('Time [s]')
ax_power_cable.set_ylabel('Power [W]')
ax_power_cable.set_title('Input power (motor) with external cable force and contact friction')
ax_power_cable.grid(True)
plt.show()

fig_force, ax_force = plt.subplots()
ax_force.plot(t, cable_force_profile, label='Cable force')
ax_force.plot(t, friction_force_profile, label='Friction force')
ax_force.set_xlabel('Time [s]')
ax_force.set_ylabel('Applied force at J [N]')
ax_force.set_title('Gradual cable contact force profile')
ax_force.grid(True)
ax_force.legend()
plt.show()
# Out:
# Motorselectie zonder penwrijving, met zwaartekracht, kabelkracht en kabelcontactwrijving:
#   Maximaal absoluut uitgangsmoment aan A = 1344.42 Nm
#   RMS uitgangsmoment aan A = 860.61 Nm
#   Maximaal absoluut uitgangsvermogen = 130.53 W
#   Gemiddeld positief vermogen = 39.08 W
#   Maximale absolute uitgangssnelheid = 1.38 rpm
#   Moment bij piekmoment: t = 9.00 s, M_A = -1344.42 Nm, n_A = -0.29 rpm
#   Vermogen bij piekvermogen: t = 12.30 s, P_A = -130.53 W, M_A = -908.28 Nm
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Dimensionering van een motor

# %% [markdown]
# Uit de Inverse dynamica: ~1350 Nm max moment
# aan ~1,3 rpm
#
# Motor met een vermogen van ~190W
#
# Gaan wel een gearbox nodig hebben om nodig moment te kunnen leveren aan een aanvaardbare stroom.
#
# Eerder zoeken naar een moment van 15~18 Nm aan bvb 100 rpm, dan met een overgang snelheid verlagen naar 1,3rpm of lager om genoeg kracht te kunnen zetten.
#
# Met een worm overgang kan dit behaald worden en dan kan de pantograaf ook niet zomaar de motor terugduwen
#
# In catalogus van ABB motors ook motoren gevonden die aan kracht voorwaarden voldoen
# Voorbeeld: ABB M3VK 80B: 0.55 kW, 6-pole, 1000 r/min class, 380–480 V, 50 Hz
# => kostprijs +-€200 [Bron](https://shop.eriks.be/nl/3-fase-motor-0-55kw-1000t-m-6p-b34t-ie3-230-400v-50hz-w22-iec-l80-gietijzer-12687343/?utm_source=google&utm_medium=cpc&utm_campaign=BE_(nl)_SEA_NB_PMAX2&utm_id=20334239514)
#
# Energiekosten om dit te runnen? => voor 6 seconden om omhoog/naar beneden te gaan => €0,005 euro aan enerie per keer
#
# Keuze versnelling: Motovario / NMRV-style combined worm gearbox NMRV-P 063 / NMRV 150, 100:1
# en een voor-reductie van 10:1
# => Deze versnelling zou veel meer kosten, tussen de €1000 en €2000

# %% [markdown]
# ### dimensioneringsvereisten uit de dynamica

# %% [markdown]
# Motor rated power:            >= 400 W (voorkeur 500W)
# Motor nominal speed:          +- 100rpm
# Required total gear ratio:    75:1 tot 100:1
# Gearbox output torque:        >= 1800 Nm
# Gearbox output speed:         about 1 to 1.5 rpm
# Gearbox type:                 worm gearbox or high-ratio planetary gearbox
# Self-locking preferred:       yes, especially for holding the pantograph position

# %% [markdown]
# # Unbalance analysis

# %% [markdown]
# De onbalanskracht (shaking force) is de kracht die de bewegende delen via de vaste scharnieren $A$, $B$ en $E$ aan het frame doorgeven. De berekende reactiekrachten zijn krachten van het frame op het mechanisme; de belasting op het frame heeft dus het tegengestelde teken:
#
# $$\mathbf{F}_{sh} = -(\mathbf{R}_A + \mathbf{R}_B + \mathbf{R}_E).$$
#
# Het onbalansmoment rond $A$ bevat ook het tegengestelde van het benodigde aandrijfmoment:
#
# $$M_{sh,A} = -\left(M_A + (\mathbf{r}_B-\mathbf{r}_A) \times \mathbf{R}_B + (\mathbf{r}_E-\mathbf{r}_A) \times \mathbf{R}_E\right).$$
#
# Eerst wordt de zuivere dynamische onbalans berekend met alleen de massatraagheid. Daarna wordt de werkelijke framebelasting tijdens werking berekend met zwaartekracht, kabelkracht en wrijving.

# %%
# Onbalansanalyse: krachten en momenten die via A, B en E op het frame werken
def frame_load_from_solution(solution):
    reaction_A = np.column_stack((solution['A_x'], solution['A_y']))
    reaction_B = np.column_stack((solution['B_x'], solution['B_y']))
    reaction_E = np.column_stack((solution['E_x'], solution['E_y']))

    frame_force = -(reaction_A + reaction_B + reaction_E)
    frame_moment_A = np.zeros(len(t))
    for k in range(len(t)):
        frame_moment_A[k] = -(
            solution['M_A'][k]
            + cross2(points['B'][k] - points['A'][k], reaction_B[k])
            + cross2(points['E'][k] - points['A'][k], reaction_E[k])
        )
    return frame_force, frame_moment_A

# Alleen inertia: dit is de dynamische onbalans van het bewegende mechanisme.
solution_inertia = bereken_krachten(masses, inertias, gravity=0.0)
unbalance_force, unbalance_moment = frame_load_from_solution(solution_inertia)

# Tijdens gebruik: totale belasting op het frame, inclusief de reeds gedefinieerde kabelkracht en wrijving.
operating_force, operating_moment = frame_load_from_solution(solution_cable)

unbalance_force_magnitude = np.linalg.norm(unbalance_force, axis=1)
operating_force_magnitude = np.linalg.norm(operating_force, axis=1)

print('Dynamische onbalans, alleen inertia:')
print(f'  Maximum kracht = {np.max(unbalance_force_magnitude):.2f} N')
print(f'  RMS kracht = {np.sqrt(np.mean(unbalance_force_magnitude**2)):.2f} N')
print(f'  Maximum absoluut moment rond A = {np.max(np.abs(unbalance_moment)):.2f} Nm')
print(f'  RMS moment rond A = {np.sqrt(np.mean(unbalance_moment**2)):.2f} Nm')
print('Totale framebelasting tijdens kabelcontact:')
print(f'  Maximum kracht = {np.max(operating_force_magnitude):.2f} N')
print(f'  Maximum absoluut moment rond A = {np.max(np.abs(operating_moment)):.2f} Nm')

fig_unbalance, ax_unbalance = plt.subplots(nrows=2, ncols=2, figsize=(12, 7), constrained_layout=True)

ax_unbalance[0, 0].plot(t, unbalance_force[:, 0], label='$F_{sh,x}$')
ax_unbalance[0, 0].plot(t, unbalance_force[:, 1], label='$F_{sh,y}$')
ax_unbalance[0, 0].set_title('Dynamische onbalanskracht')
ax_unbalance[0, 0].set_ylabel('Force [N]')
ax_unbalance[0, 0].legend()

ax_unbalance[0, 1].plot(t, unbalance_moment, label='$M_{sh,A}$')
ax_unbalance[0, 1].set_title('Dynamisch onbalansmoment rond A')
ax_unbalance[0, 1].set_ylabel('Moment [Nm]')
ax_unbalance[0, 1].legend()

ax_unbalance[1, 0].plot(t, operating_force_magnitude, label='$|F_{frame}|$')
ax_unbalance[1, 0].set_title('Totale framekracht tijdens werking')
ax_unbalance[1, 0].set_ylabel('Force [N]')
ax_unbalance[1, 0].legend()

ax_unbalance[1, 1].plot(t, operating_moment, label='$M_{frame,A}$')
ax_unbalance[1, 1].set_title('Totaal framemoment rond A')
ax_unbalance[1, 1].set_ylabel('Moment [Nm]')
ax_unbalance[1, 1].legend()

for ax in ax_unbalance.flat:
    ax.set_xlabel('Time [s]')
    ax.grid(True)

plt.show()
# Out:
# Dynamische onbalans, alleen inertia:
#   Maximum kracht = 7.13 N
#   RMS kracht = 4.63 N
#   Maximum absoluut moment rond A = 8.02 Nm
#   RMS moment rond A = 5.08 Nm
# Totale framebelasting tijdens kabelcontact:
#   Maximum kracht = 733.06 N
#   Maximum absoluut moment rond A = 1019.93 Nm
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
