# %% [markdown]
# # De 10 vragen hulp

# %% [markdown]
# **1. waarvoor gebruikt de industrie het mechanisme of de nok? Hoe aanpassen voor andere toepassing**
#
# Stangenmechanisme => pantograaf of stroomafnemer van een (hogesnelheidstrein) trein
#
# **2. Hoe optimaliseren voor precisie, energieverbruik of krachtgeneratie**
#
# **3. Vliegwiel trade offs**
#
# **4. Bewegingstraject trade offs**
#
# => Pantograaf moest "plat" kunnen opplooien => aerodynamica.
# Maar dit zorgde voor een kortere aandrijfstang en dus grotere krachten/momenten op de motor/aandrijving.
#
# **5. hoe gebruik je de analyse van de frequentie-inhoud van je ontwerp?**
#
# **6. Dode punten / singulariteiten? is dat erg?**
#
# **7. Onbalans eigenschappen? zorgt dit voor problemen?**
#
# **8. relatieve invloed van inertie, wrijving en stijfheid?**
#
# **9. Verschillende koppies in parallel aandrijven met zelfde motor?**
#
# meerdere stroomafnames op een trein => aandrijven met 1 motor en dan met ontkoppelingen individueel kunnen naar boven en naar beneden laten gaan.
#
# **10. verander een parameter en voorspel wat het effect zal zijn**
#
# **Motor prijs en energieverbruik**
# Stangenmechanisme => ABB motor +-€200 en energieverbruik van +- €0,005 per cyclus

# %% [markdown]
# TODO
#
# Invloed van de stijfheid van de stangen in beeld brengen.
#
# Frequentie diagram massa, veer demper systeem => voor de volger van de nok
